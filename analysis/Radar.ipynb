# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../python'))                                                                                                                         
if module_path not in sys.path:
    sys.path.append(module_path)

import scraping
import imageio
import requests as r
import rnn_functions
from logfuncts import logger, logging

logger.setLevel(logging.INFO)

# %%
filename = "2019-04-04T06:00:00.png"
with open("../image/radar/" + filename, "r") as ff:                                                                                                 
    image = imageio.imread(ff)
                                                  
rain = scraping.rain_from_radar(image, river="dart")

# %%
train_df, test_df = rnn_functions.load_data(
    start_date = "2017-12-10 16:15:00",
    end_date = "2019-04-14 11:45:00"
)
